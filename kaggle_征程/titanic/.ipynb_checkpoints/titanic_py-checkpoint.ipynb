# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import matplotlib.pyplot as plt
import os
from sklearn import preprocessing
from patsy import dmatrices
from operator import itemgetter
import json

#from sklearn.pipeline import Pipeline
#from sklearn.grid_search import GridSearchCV
from sklearn.cross_validation import train_test_split,StratifiedShuffleSplit,StratifiedKFold
from sklearn.metrics import classification_report
from sklearn.externals import joblib

from sklearn import linear_model
from sklearn import svm
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import BaggingRegressor, BaggingClassifier, RandomForestClassifier, RandomForestRegressor

# %%
'''
画图显示中文
'''
#-*- coding: utf-8 -*-
from matplotlib.font_manager import FontProperties
font = FontProperties(fname=r"c:\windows\fonts\simsun.ttc", size=14)

# %%
trainFile = r'E:\jupyter notebook\kaggle\titanic\titanic_data\train.csv'
pwd = os.getcwd()
os.chdir(os.path.dirname(trainFile))
trainSet = pd.read_csv(os.path.basename(trainFile), date_parser = True)
os.chdir(pwd)
trainSet
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %% [markdown]
# 1.下面的分析表明训练集中：Age有缺失值177个,总共有891个数据,Cabin有204个缺失值,Embarked有2个缺失值
# 2. 314个女性，577个男性,女性存活了233个，男性存活了109个，总共活了342
# 3. 年龄存活区间：(0, 18):61个 [18, 30):95个，[30,55):121 [55:] : 13个, 没有统计的人数活了52个
# 4. 阶层为3的活了119人， 阶层为2的活了87人， 阶层为1的活了136人
# 5. 登录港口为'S'的活了217人，'C'的活了93人， 'Q'的活了30人

# %%
trainSet.info()
trainSet.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# ...

# %%
fig = plt.figure()
#fig.set(alpha = 0.2)

plt.subplot2grid((2, 3), (0, 0))
trainSet.Survived.value_counts().plot(kind = 'bar')
plt.ylabel('Number of save(not save)')
plt.title('Saved people')
plt.grid(True)

plt.subplot2grid((2, 3), (0, 1))
trainSet.Pclass.value_counts().plot(kind = 'bar')
plt.ylabel('Numbers')
plt.title('Pclass')
plt.grid(True)

plt.subplot2grid((2, 3), (0, 2))
plt.scatter(trainSet.Survived, trainSet.Age)
plt.grid(True)
plt.title('Age')

plt.subplot2grid((2, 3), (1, 0), colspan=2)  #占举两格
trainSet['Age'][trainSet['Pclass'] == 1].plot(kind = 'kde', label = 'p1')
trainSet['Age'][trainSet['Pclass'] == 2].plot(kind = 'kde', label = 'p2')
trainSet['Age'][trainSet['Pclass'] == 3].plot(kind = 'kde', label = 'p3')
plt.legend(loc = 'best')
plt.title(u'各舱年龄的密度图',  fontproperties=font)

plt.subplot2grid((2, 3), (1, 2))
trainSet.Embarked.value_counts().plot(kind = 'bar')
plt.title('Embarked')
plt.grid(True)

plt.show()

# %%
fig = plt.figure()
fig.set(alpha = 0.2)

Survived_0 = trainSet.Pclass[trainSet.Survived == 0].value_counts()
Survived_1 = trainSet.Pclass[trainSet.Survived == 1].value_counts()
df = DataFrame({'Saved':Survived_1, 'Not Saved':Survived_0})

df.plot(kind = 'bar', stacked = True)
plt.xlabel(u'舱的等级', fontproperties = font)
plt.ylabel(u'人数', fontproperties = font)
plt.legend(loc = 'best')

plt.show()

# %%
fig = plt.figure()
fig.set(alpha = 0.2)

Survived_0 = trainSet.Sex[trainSet.Survived == 0].value_counts()
Survived_1 = trainSet.Sex[trainSet.Survived == 1].value_counts()
df = DataFrame({'Saved':Survived_1, 'Not Saved':Survived_0})

df.plot(kind = 'bar', stacked = True)
plt.xlabel(u'性别', fontproperties = font)
plt.ylabel(u'人数', fontproperties = font)
plt.legend(loc = 'best')

plt.show()

# %%
fig = plt.figure()
fig.set(alpha = 0.2)
#plt.title(u'根据各舱和性别的对别分析', fontproperties = font)

ax1 = fig.add_subplot(141)
trainSet.Survived[trainSet.Sex == 'female'][trainSet.Pclass != 3].value_counts().plot(kind = 'bar', label = u'女/高')
ax1.legend(loc = 'best',  prop =  font)

ax2 = fig.add_subplot(142, sharey = ax1)
trainSet.Survived[trainSet.Sex == 'female'][trainSet.Pclass == 3].value_counts().plot(kind = 'bar', label = u'女/低')
ax2.legend(loc = 'best',  prop =  font)

ax3 = fig.add_subplot(143, sharey = ax1)
trainSet.Survived[trainSet.Sex == 'male'][trainSet.Pclass != 3].value_counts().plot(kind = 'bar', label = u'男/高')
ax3.legend(loc = 'best',  prop =  font)

ax4 = fig.add_subplot(144, sharey = ax1)
trainSet.Survived[trainSet.Sex == 'male'][trainSet.Pclass == 3].value_counts().plot(kind = 'bar', label = u'男/低')
ax4.legend(loc = 'best',  prop =  font)


plt.show()

# %%
fig = plt.figure()
fig.set(alpha = 0.2)

Survived_0 = trainSet.Embarked[trainSet.Survived == 0].value_counts()
Survived_1 = trainSet.Embarked[trainSet.Survived == 1].value_counts()
df = DataFrame({'Saved':Survived_1, 'Not Saved':Survived_0})

df.plot(kind = 'bar', stacked = True)
plt.xlabel(u'等船口', fontproperties = font)
plt.ylabel(u'人数', fontproperties = font)
plt.legend(loc = 'best')

plt.show()

# %%
g = trainSet.groupby(['Parch', 'Survived'])
df = pd.DataFrame(g.count())
df
# Out:
#                 PassengerId  Pclass  Name  Sex  Age  SibSp  Ticket  Fare  \
# Parch Survived
# 0     0                 445     445   445  445  335    445     445   445
#       1                 233     233   233  233  186    233     233   233
# 1     0                  53      53    53   53   49     53      53    53
#       1                  65      65    65   65   61     65      65    65
# 2     0                  40      40    40   40   29     40      40    40
#       1                  40      40    40   40   39     40      40    40
# 3     0                   2       2     2    2    2      2       2     2
#       1                   3       3     3    3    3      3       3     3
# 4     0                   4       4     4    4    4      4       4     4
# 5     0                   4       4     4    4    4      4       4     4
#       1                   1       1     1    1    1      1       1     1
# 6     0                   1       1     1    1    1      1       1     1
#
# ...

# %%
fig = plt.figure()
fig.set(alpha = 0.2)

Cabin_null = trainSet.Survived[trainSet.Cabin.isnull()].value_counts()
Cabin_notnull = trainSet.Survived[trainSet.Cabin.notnull()].value_counts()
df = DataFrame({'没有标注信息':Cabin_null, '有标注信息':Cabin_notnull})

df.plot(kind = 'bar', stacked = True)
plt.xlabel(u'生存与否', fontproperties = font)
plt.ylabel(u'人数', fontproperties = font)
plt.legend(loc = 'best', prop = font)

plt.show()

# %%
trainSet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
trainSet[:1]
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
#数据预处理
trainFile = r'E:\jupyter notebook\kaggle\titanic\titanic_data\train.csv'
pwd = os.getcwd()
os.chdir(os.path.dirname(trainFile))
trainSet = pd.read_csv(os.path.basename(trainFile), date_parser = True)
os.chdir(pwd)
trainSet[:6]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
trainSet['Sex_Pclass'] = trainSet['Sex'] + '_' + trainSet['Pclass'].map(str)  #将性别和Pclass单独组合起来成为一个新的属性

# %%
from sklearn.ensemble import RandomForestRegressor

def set_missing_ages(trainSet): #填补缺失的年龄值
    age_data = trainSet[['Age', 'Pclass', 'SibSp', 'Parch', 'Fare']]

    known_age = np.mat(age_data[age_data.Age.notnull()])
    unknown_age = np.mat(age_data[age_data.Age.isnull()])
    
    Y = known_age[:, 0]
    X = known_age[:, 1:]
    
    clf = RandomForestRegressor(random_state = 0, n_estimators = 2000)
    clf.fit(X, Y)
    print(clf.score(X, Y))
    

    predict_age = clf.predict(unknown_age[:, 1:])
    trainSet.loc[(trainSet.Age.isnull()), 'Age' ] = predict_age
    return trainSet

def set_cabin_numer(trainSet):  #将cabin的缺失值转换为数值型
    trainSet.loc[(trainSet.Cabin.notnull()), 'Cabin' ] = 'Yes'
    trainSet.loc[(trainSet.Cabin.isnull()), 'Cabin' ] = 'No'
    
    return trainSet

train = trainSet
trainSet_pro = set_missing_ages(train)
trainSet_pro = set_cabin_numer(trainSet_pro)
# Out:
# D:\ANACONDA\lib\site-packages\ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
# 0.646244066314

# %%
trainSet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            891 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          891 non-null object
# Embarked       889 non-null object
# Sex_Pclass     891 non-null object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 90.6+ KB

# %%
dummies_Cabin = pd.get_dummies(trainSet['Cabin'], prefix= 'Cabin')

dummies_Embarked = pd.get_dummies(trainSet['Embarked'], prefix= 'Embarked')

dummies_Sex = pd.get_dummies(trainSet['Sex'], prefix= 'Sex')

dummies_Pclass = pd.get_dummies(trainSet['Pclass'], prefix= 'Pclass')

dummies_Sex_Pclass = pd.get_dummies(trainSet['Sex_Pclass'], prefix= 'Sex_Pclass')

df = pd.concat([trainSet, dummies_Cabin, dummies_Embarked, dummies_Sex, dummies_Pclass, dummies_Sex_Pclass], axis=1)
df.drop(['Pclass', 'Sex', 'Cabin', 'Embarked', 'Sex_Pclass'], axis=1, inplace=True)

# %%
df
# Out:
#      PassengerId  Survived                                               Name  \
# 0              1         0                            Braund, Mr. Owen Harris
# 1              2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3         1                             Heikkinen, Miss. Laina
# 3              4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5         0                           Allen, Mr. William Henry
# 5              6         0                                   Moran, Mr. James
# 6              7         0                            McCarthy, Mr. Timothy J
# 7              8         0                     Palsson, Master. Gosta Leonard
# 8              9         1  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9             10         1                Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1                    Sandstrom, Miss. Marguerite Rut
# ...

# %%
#数据预处理，归一化
scaler = preprocessing.StandardScaler()
age_scaler = scaler.fit(np.array(df['Age'].values.reshape(-1, 1)))
df['Age_scaled'] = age_scaler.transform(np.array(df['Age'].values.reshape(-1, 1)))

fare_scaler = scaler.fit(np.array(df['Fare'].values.reshape(-1, 1)))
df['Fare_scaled'] = fare_scaler.transform(np.array(df['Fare'].values.reshape(-1, 1)))

# %%
from sklearn import linear_model
from sklearn import svm
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import BaggingRegressor, BaggingClassifier, RandomForestClassifier, RandomForestRegressor

trainSet_df = df.filter(regex='Survived|Age_.*|SibSp|Parch|Fare_.*|Cabin_.*|Embarked_.*|Sex_.*|Pclass_.*|Sex_Pclass_.*')
train_df = trainSet_df.as_matrix()

Y = train_df[:, 0]
X = train_df[:, 1:]

#clf = linear_model.LogisticRegression(penalty = 'l1' ,max_iter = 100, tol = 1e-6)
#clf = RandomForestRegressor(n_estimators=20, random_state = 0, max_depth = None)
clf = svm.SVC()
#bagging_clf = BaggingRegressor(clf, n_estimators=20, max_samples=0.8)
    
#trainModel = clf.fit(X, Y)
#cross_val_score(clf, X, Y, cv=5)
#bagging_clf.fit(X, Y)
#clf.score(X, Y)

# %%
from sklearn.model_selection import train_test_split

split_train, split_cv = train_test_split(df, test_size=0.3, random_state=0)

train_cross = split_train.filter(regex='Survived|Age_.*|SibSp|Parch|Fare_.*|Cabin_.*|Embarked_.*|Sex_.*|Pclass_.*|Sex_Pclass_.*')
crossModel = clf.fit(train_cross.as_matrix()[:, 1:], train_cross.as_matrix()[:, 0])

test_cross = split_cv.filter(regex='Survived|Age_.*|SibSp|Parch|Fare_.*|Cabin_.*|Embarked_.*|Sex_.*|Pclass_.*|Sex_Pclass_.*')
crossModel.score(test_cross.as_matrix()[:, 1:], test_cross.as_matrix()[:, 0])
# Out:
# 0.80597014925373134

# %%
#观察系数之间的关系
pd.DataFrame({"columns":list(trainSet_df.columns)[1:], "coef":list(bagging_clf.coef_.T)})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-ec7fb9db4208> in <module>()
#       1 #观察系数之间的关系
# ----> 2 pd.DataFrame({"columns":list(trainSet_df.columns)[1:], "coef":list(bagging_clf.coef_.T)})
#
# AttributeError: 'BaggingRegressor' object has no attribute 'coef_'

# %%
pred_X = clf.predict(test_cross.as_matrix()[:, 1:])
pred_X[pred_X <= 0.5] = 0
pred_X[pred_X > 0.5] = 1
np.sum(pred_X == test_cross.as_matrix()[:, 0])/len(pred_X)
# Out:
# 0.80597014925373134

# %%
from sklearn.model_selection import train_test_split

split_train, split_cv = train_test_split(df, test_size=0.3, random_state=0)

train_cross = split_train.filter(regex='Survived|Age_.*|SibSp|Parch|Fare_.*|Cabin_.*|Embarked_.*|Sex_.*|Pclass_.*')
crossModel = clf.fit(train_cross.as_matrix()[:, 1:], train_cross.as_matrix()[:, 0])

test_cross = split_cv.filter(regex='Survived|Age_.*|SibSp|Parch|Fare_.*|Cabin_.*|Embarked_.*|Sex_.*|Pclass_.*')
pred_cross = crossModel.predict(test_cross.as_matrix()[:, 1:]).astype(int)

trainFile = r'E:\jupyter notebook\kaggle\titanic\titanic_data\train.csv'
pwd = os.getcwd()
os.chdir(os.path.dirname(trainFile))
origin_train_data = pd.read_csv(os.path.basename(trainFile), date_parser = True)
os.chdir(pwd)

bad_cases = origin_train_data.loc[origin_train_data['PassengerId'].isin(split_cv[pred_cross != 
                                                    test_cross.as_matrix()[:, 0]]['PassengerId'])]
bad_cases
# Out:
#      PassengerId  Survived  Pclass  \
# 14            15         0       3
# 18            19         0       3
# 27            28         0       1
# 40            41         0       3
# 49            50         0       3
# 55            56         1       1
# 65            66         1       3
# 68            69         1       3
# 85            86         1       3
# 97            98         1       1
# 113          114         0       3
# 140          141         0       3
# 204          205         1       3
# 240          241         0       3
# 251          252         0       3
# 261          262         1       3
# 264          265         0       3
# 267          268         1       3
# 271          272         1       3
# 283          284         1       3
# 293          294         0       3
# 298          299         1       1
# 301          302         1       3
# 312          313         0       2
# 338          339         1       3
# ...

# %%
from sklearn.learning_curve import learning_curve

# 用sklearn的learning_curve得到training_score和cv_score，使用matplotlib画出learning curve
def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None, n_jobs=1, 
                        train_sizes=np.linspace(.05, 1., 20), verbose=0, plot=True):
    """
    画出data在某模型上的learning curve.
    参数解释
    ----------
    estimator : 你用的分类器。
    title : 表格的标题。
    X : 输入的feature，numpy类型
    y : 输入的target vector
    ylim : tuple格式的(ymin, ymax), 设定图像中纵坐标的最低点和最高点
    cv : 做cross-validation的时候，数据分成的份数，其中一份作为cv集，其余n-1份作为training(默认为3份)
    n_jobs : 并行的的任务数(默认1)
    """
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes, verbose=verbose)

    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)

    if plot:
        plt.figure()
        plt.title(title, fontproperties = font)
        if ylim is not None:
            plt.ylim(*ylim)
        plt.xlabel(u"训练样本数", fontproperties = font)
        plt.ylabel(u"得分", fontproperties = font)
        plt.gca()
        plt.grid()

        plt.fill_between(train_sizes, train_scores_mean - train_scores_std, train_scores_mean + train_scores_std, 
                         alpha=0.1, color="b")
        plt.fill_between(train_sizes, test_scores_mean - test_scores_std, test_scores_mean + test_scores_std, 
                         alpha=0.1, color="r")
        plt.plot(train_sizes, train_scores_mean, 'o-', color="b", label=u"训练集上得分")
        plt.plot(train_sizes, test_scores_mean, 'o-', color="r", label=u"交叉验证集上得分")

        plt.legend(loc="best", prop = font)

        plt.draw()
        plt.show()

    midpoint = ((train_scores_mean[-1] + train_scores_std[-1]) + (test_scores_mean[-1] - test_scores_std[-1])) / 2
    diff = (train_scores_mean[-1] + train_scores_std[-1]) - (test_scores_mean[-1] - test_scores_std[-1])
    return midpoint, diff

plot_learning_curve(clf, u"学习曲线", X, Y)
# Out:
# (0.82201286745269142, 0.028308650791321277)

# %%
#数据预处理
trainFile = r'E:\jupyter notebook\kaggle\titanic\titanic_data\test.csv'
pwd = os.getcwd()
os.chdir(os.path.dirname(trainFile))
testSet = pd.read_csv(os.path.basename(trainFile), date_parser = True)
os.chdir(pwd)
testSet[:11]
# Out:
#     PassengerId  Pclass                                          Name     Sex  \
# 0           892       3                              Kelly, Mr. James    male
# 1           893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2           894       2                     Myles, Mr. Thomas Francis    male
# 3           895       3                              Wirz, Mr. Albert    male
# 4           896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5           897       3                    Svensson, Mr. Johan Cervin    male
# 6           898       3                          Connolly, Miss. Kate  female
# 7           899       2                  Caldwell, Mr. Albert Francis    male
# 8           900       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9           901       3                       Davies, Mr. John Samuel    male
# 10          902       3                              Ilieff, Mr. Ylio    male
#
# ...

# %%
testSet.loc[testSet.Fare.isnull(), 'Fare'] = 0
testSet.info()
testSet['Sex_Pclass'] = testSet['Sex'] + '_' + testSet['Pclass'].map(str)  #将性别和Pclass单独组合起来成为一个新的属性
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           418 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
testSet = set_missing_ages(testSet)
testSet = set_cabin_numer(testSet)

dummies_Cabin = pd.get_dummies(testSet['Cabin'], prefix= 'Cabin')

dummies_Embarked = pd.get_dummies(testSet['Embarked'], prefix= 'Embarked')

dummies_Sex = pd.get_dummies(testSet['Sex'], prefix= 'Sex')

dummies_Pclass = pd.get_dummies(testSet['Pclass'], prefix= 'Pclass')

dummies_Sex_Pclass = pd.get_dummies(testSet['Sex_Pclass'], prefix= 'Sex_Pclass')

tf = pd.concat([testSet, dummies_Cabin, dummies_Embarked, dummies_Sex, dummies_Pclass, dummies_Sex_Pclass], axis=1)
tf.drop(['Pclass', 'Sex', 'Cabin', 'Embarked', 'Sex_Pclass'], axis=1, inplace=True)
# Out:
# D:\ANACONDA\lib\site-packages\ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
# 0.758987267777

# %%
#归一化
tf['Age_scaled'] = age_scaler.transform(tf['Age'].as_matrix().reshape(-1, 1))

tf['Fare_scaled'] = age_scaler.transform(np.array(tf['Fare'].values.reshape(-1, 1)))

# %%
tf
# Out:
#      PassengerId                                               Name  \
# 0            892                                   Kelly, Mr. James
# 1            893                   Wilkes, Mrs. James (Ellen Needs)
# 2            894                          Myles, Mr. Thomas Francis
# 3            895                                   Wirz, Mr. Albert
# 4            896       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897                         Svensson, Mr. Johan Cervin
# 6            898                               Connolly, Miss. Kate
# 7            899                       Caldwell, Mr. Albert Francis
# 8            900          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9            901                            Davies, Mr. John Samuel
# 10           902                                   Ilieff, Mr. Ylio
# 11           903                         Jones, Mr. Charles Cresson
# 12           904      Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# ...

# %%
test = tf.filter(regex='Age_.*|SibSp|Parch|Fare_.*|Cabin_.*|Embarked_.*|Sex_.*|Pclass_.*|Sex_Pclass_.*')
X_test = test.as_matrix()

predictions = clf.predict(X_test)

#predictions[predictions < 0.5] = 0
#predictions[predictions >= 0.5] = 1

# %%
#将结果写进csv格式文件
result = pd.DataFrame({'PassengerId':testSet['PassengerId'].as_matrix(), 'Survived':predictions.astype(int)})
result.to_csv(r"E:\jupyter notebook\kaggle\titanic\pred_label\predict.csv", index=False)

# %%
pd.read_csv(r"E:\jupyter notebook\kaggle\titanic\pred_label\predict.csv")
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# 5            897         0
# 6            898         1
# 7            899         0
# 8            900         1
# 9            901         0
# 10           902         0
# 11           903         0
# 12           904         1
# 13           905         0
# 14           906         1
# 15           907         1
# 16           908         0
# 17           909         0
# 18           910         1
# 19           911         1
# 20           912         0
# 21           913         0
# 22           914         1
# 23           915         0
# 24           916         1
# 25           917         0
# 26           918         1
# 27           919         0
# 28           920         0
# 29           921         0
# ..           ...       ...
# 388         1280         0
# 389         1281         0
# ...

# %%
#数据预处理
trainFile = r'E:\jupyter notebook\kaggle\titanic\titanic_data\train.csv'
pwd = os.getcwd()
os.chdir(os.path.dirname(trainFile))
trainSet = pd.read_csv(os.path.basename(trainFile), date_parser = True)
os.chdir(pwd)
trainSet[:6]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
trainSet['Sex_Pclass'] = trainSet['Sex'] + '_' + trainSet['Pclass'].map(str)  #将性别和Pclass单独组合起来成为一个新的属性

# %%
def feature_extract(trainSet):
    import string, re
    def substrings_in_string(big_string, substrings):
        for substring in substrings:
            if big_string.find(substring) != -1:
                return substring
        print(big_string)
        return np.nan

    title_list=['Mrs', 'Mr', 'Master', 'Miss', 'Major', 'Rev',
                    'Dr', 'Ms', 'Mlle','Col', 'Capt', 'Mme', 'Countess',
                    'Don', 'Jonkheer']
    trainSet['Title']=trainSet['Name'].map(lambda x: substrings_in_string(x, title_list))

    def replace_titles(x):
            title=x['Title']
            if title in ['Mr','Don', 'Major', 'Capt', 'Jonkheer', 'Rev', 'Col']:
                return 'Mr'
            elif title in ['Master']:
                return 'Master'
            elif title in ['Countess', 'Mme','Mrs']:
                return 'Mrs'
            elif title in ['Mlle', 'Ms','Miss']:
                return 'Miss'
            elif title =='Dr':
                if x['Sex']=='Male':
                    return 'Mr'
                else:
                    return 'Mrs'
            elif title =='':
                if x['Sex']=='Male':
                    return 'Master'
                else:
                    return 'Miss'
            else:
                return title

    trainSet['Title'] = trainSet.apply(replace_titles, axis = 1)

    trainSet['AgeFill'] = trainSet['Age']
    mean_fill = np.zeros(4)
    mean_fill[0] = np.average(trainSet[trainSet['Title'] == 'Mr']['Age'].dropna())
    mean_fill[1] = np.average(trainSet[trainSet['Title'] == 'Mrs']['Age'].dropna())
    mean_fill[2] = np.average(trainSet[trainSet['Title'] == 'Miss']['Age'].dropna())
    mean_fill[3] = np.average(trainSet[trainSet['Title'] == 'Master']['Age'].dropna())

    trainSet.loc[ (trainSet.Age.isnull()) & (trainSet.Title == 'Mr') ,'AgeFill'] = mean_fill[0]
    trainSet.loc[ (trainSet.Age.isnull()) & (trainSet.Title == 'Mrs') ,'AgeFill'] = mean_fill[1]
    trainSet.loc[ (trainSet.Age.isnull()) & (trainSet.Title == 'Miss') ,'AgeFill'] = mean_fill[2]
    trainSet.loc[ (trainSet.Age.isnull()) & (trainSet.Title == 'Master') ,'AgeFill'] = mean_fill[3]

    trainSet['AgeCat'] = trainSet['AgeFill']
    trainSet.loc[(trainSet.AgeFill <= 10), 'AgeCat'] = 'child'
    trainSet.loc[(trainSet.AgeFill > 10) & (trainSet.AgeFill <= 30), 'AgeCat'] = 'adult'
    trainSet.loc[(trainSet.AgeFill > 30) & (trainSet.AgeFill <= 60), 'AgeCat'] = 'Senior'
    trainSet.loc[(trainSet.AgeFill > 60), 'AgeCat'] = 'old'

    trainSet.loc[trainSet.Embarked.isnull(), 'Embarked'] = 'S'
    trainSet.loc[trainSet.Cabin.isnull(), 'Cabin'] = 0.5
    trainSet.loc[trainSet.Cabin.notnull(), 'Cabin'] = 1.5

    trainSet['family_size'] = trainSet.SibSp + trainSet.Parch
    trainSet['family'] = trainSet.SibSp * trainSet.Parch

    trainSet['Fare_Per_Person']=trainSet['Fare']/(trainSet['family_size'] + 1)

    #Age times class
    trainSet['AgeClass']=trainSet['AgeFill'] * trainSet['Pclass']
    trainSet['ClassFare']=trainSet['Pclass'] * trainSet['Fare_Per_Person']

    trainSet['HighLow']=trainSet['Pclass']
    trainSet.loc[ (trainSet.Fare_Per_Person < 8) ,'HighLow'] = 'Low'
    trainSet.loc[ (trainSet.Fare_Per_Person >= 8) ,'HighLow'] = 'High'

    le = preprocessing.LabelEncoder()
    '''
    from sklearn.preprocessing import LabelEncoder
    le = LabelEncoder()
    le.fit([1,5,67,100])
    le.transform([1,1,100,67,5])
    输出： array([0,0,3,2,1])
    '''

    le.fit(trainSet['Sex'] )
    x_sex=le.transform(trainSet['Sex'])
    trainSet['Sex']=x_sex.astype(np.float)

    le.fit( trainSet['Ticket'])
    x_Ticket=le.transform( trainSet['Ticket'])
    trainSet['Ticket']=x_Ticket.astype(np.float)

    le.fit(trainSet['Title'])
    x_title=le.transform(trainSet['Title'])
    trainSet['Title'] =x_title.astype(np.float)

    le.fit(trainSet['HighLow'])
    x_hl=le.transform(trainSet['HighLow'])
    trainSet['HighLow']=x_hl.astype(np.float)


    le.fit(trainSet['AgeCat'])
    x_age=le.transform(trainSet['AgeCat'])
    trainSet['AgeCat'] =x_age.astype(np.float)

    le.fit(trainSet['Embarked'])
    x_emb=le.transform(trainSet['Embarked'])
    trainSet['Embarked']=x_emb.astype(np.float)

    trainSet = trainSet.drop(['PassengerId','Name','Age'], axis = 1)
    
    return trainSet


trainSet = feature_extract(trainSet)
'''
formula_ml='Survived~Pclass+C(Title)+Sex+C(AgeCat)+Fare_Per_Person+Fare+family_size' 

y_train, x_train = dmatrices(formula_ml, data=trainSet, return_type='dataframe')
y_train = np.asarray(y_train).ravel()

'''
# Out:
# "\nformula_ml='Survived~Pclass+C(Title)+Sex+C(AgeCat)+Fare_Per_Person+Fare+family_size' \n\ny_train, x_train = dmatrices(formula_ml, data=trainSet, return_type='dataframe')\ny_train = np.asarray(y_train).ravel()\n\n"

# %%
dummies_Embarked = pd.get_dummies(trainSet['Embarked'], prefix= 'Embarked')

dummies_Sex = pd.get_dummies(trainSet['Sex'], prefix= 'Sex')

dummies_Pclass = pd.get_dummies(trainSet['Pclass'], prefix= 'Pclass')

dummies_Sex_Pclass = pd.get_dummies(trainSet['Sex_Pclass'], prefix= 'Sex_Pclass')

dummies_Title = pd.get_dummies(trainSet['Title'], prefix= 'Title')

dummies_AgeCat = pd.get_dummies(trainSet['AgeCat'], prefix= 'AgeCat')

dummies_HighLow = pd.get_dummies(trainSet['HighLow'], prefix= 'HighLow')

df = pd.concat([trainSet, dummies_Embarked, dummies_Sex, dummies_Pclass, dummies_Sex_Pclass, dummies_Title, dummies_AgeCat, dummies_HighLow], axis=1)
df.drop(['Fare', 'Pclass', 'Sex',  'Embarked', 'Sex_Pclass', 'Title', 'AgeCat', 'HighLow'], axis=1, inplace=True)

#数据预处理，归一化
scaler = preprocessing.StandardScaler()
age_scaler = scaler.fit(np.array(df['AgeFill'].values.reshape(-1, 1)))
df['Age_scaled'] = age_scaler.transform(np.array(df['AgeFill'].values.reshape(-1, 1)))

fare_scaler = scaler.fit(np.array(df['Fare_Per_Person'].values.reshape(-1, 1)))
df['Fare_Per_Person_scaled'] = fare_scaler.transform(np.array(df['Fare_Per_Person'].values.reshape(-1, 1)))

AgeClass_scaler = scaler.fit(np.array(df['AgeClass'].values.reshape(-1, 1)))
df['AgeClass'] = AgeClass_scaler.transform(np.array(df['AgeClass'].values.reshape(-1, 1)))

ClassFare_scaler = scaler.fit(np.array(df['ClassFare'].values.reshape(-1, 1)))
df['ClassFare'] = ClassFare_scaler.transform(np.array(df['ClassFare'].values.reshape(-1, 1)))

# %%
df.drop(['Ticket', 'SibSp', 'Parch', 'AgeFill', 'Fare_Per_Person'], axis=1, inplace=True)

# %%
df
# Out:
#      Survived Cabin  family_size  family  AgeClass  ClassFare  Embarked_0.0  \
# 0           0   1.5            1       0  0.027855  -0.572023             0
# 1           1   1.5            1       0 -0.804057   0.116191             1
# 2           1   1.5            0       0  0.384389  -0.213559             0
# 3           1   1.5            1       0 -0.893191  -0.136447             0
# 4           0   1.5            0       0  1.186590  -0.203138             0
# 5           0   1.5            0       0  0.998696  -0.169101             0
# 6           0   1.5            0       0 -0.328679   0.566935             0
# 7           0   1.5            4       3 -1.754814  -0.522838             0
# 8           1   1.5            2       0  0.473522  -0.564845             0
# 9           1   1.5            1       0 -1.101169  -0.038611             1
# 10          1   1.5            2       1 -1.576548  -0.410158             0
# ...

# %%
#X_train, X_test, Y_train, Y_test = train_test_split(x_train, y_train, test_size=0.2,random_state=0)

trainSet_df = df.filter(regex='Survived|Cabin|family_size|family|AgeClass|ClassFare|Embarked_.*|Sex_.*|Title_.*|\
                        Sex_Pclass_.*|HighLow_.*|Pclass_.*|AggCat_.*|Age_scaled|Fare_Per_Person_scaled')
train_df = trainSet_df.as_matrix()

Y = train_df[:, 0]
X = train_df[:, 1:]


clf = linear_model.LogisticRegression(penalty = 'l1' ,max_iter = 100, tol = 1e-6)
#clf = RandomForestRegressor(n_estimators=20, random_state = 0, max_depth = None)
#clf = svm.SVC()
bagging_clf = BaggingRegressor(clf, n_estimators=20, max_samples=0.8)
    
#trainModel = clf.fit(X, Y)
#cross_val_score(clf, X, Y, cv=5)
#bagging_clf.fit(X, Y)
#clf.score(X, Y)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, test_size=0.3, random_state=0)

#train_cross = split_train.filter(regex='Survived|Age_.*|SibSp|Parch|Fare_.*|Cabin_.*|Embarked_.*|Sex_.*|Pclass_.*|Sex_Pclass_.*')
crossModel = bagging_clf.fit(x_train, y_train)

#test_cross = split_cv.filter(regex='Survived|Age_.*|SibSp|Parch|Fare_.*|Cabin_.*|Embarked_.*|Sex_.*|Pclass_.*|Sex_Pclass_.*')
crossModel.score(x_test, y_test)
# Out:
# 0.37413872867099252

# %%
pred_X = bagging_clf.predict(x_test)
pred_X[pred_X <= 0.5] = 0
pred_X[pred_X > 0.5] = 1
np.sum(pred_X == y_test)/len(pred_X)
# Out:
# 0.84491978609625673

# %%
pred = clf.predict(x_train)
#将结果写进csv格式文件
result = pd.DataFrame({'PassengerId':testSet['PassengerId'].as_matrix(), 'Survived':predictions.astype(int)})
result.to_csv(r"E:\jupyter notebook\kaggle\titanic\pred_label\predict.csv", index=False)

# %%
import string, re
def substrings_in_string(big_string, substrings):
    for substring in substrings:
        if big_string.find(substring) != -1:
            return substring
    print(big_string)
    return np.nan

# %%
title_list=['Mrs', 'Mr', 'Master', 'Miss', 'Major', 'Rev',
                'Dr', 'Ms', 'Mlle','Col', 'Capt', 'Mme', 'Countess',
                'Don', 'Jonkheer']
trainSet['Title']=trainSet['Name'].map(lambda x: substrings_in_string(x, title_list))

# %%
trainSet['Title'] = trainSet.apply(replace_titles, axis = 1)

# %%
def replace_titles(x):
        title=x['Title']
        if title in ['Mr','Don', 'Major', 'Capt', 'Jonkheer', 'Rev', 'Col']:
            return 'Mr'
        elif title in ['Master']:
            return 'Master'
        elif title in ['Countess', 'Mme','Mrs']:
            return 'Mrs'
        elif title in ['Mlle', 'Ms','Miss']:
            return 'Miss'
        elif title =='Dr':
            if x['Sex']=='Male':
                return 'Mr'
            else:
                return 'Mrs'
        elif title =='':
            if x['Sex']=='Male':
                return 'Master'
            else:
                return 'Miss'
        else:
            return title

# %%
trainSet = feature_extract(testSet)
formula_ml='1~Pclass+C(Title)+Sex+C(AgeCat)+Fare_Per_Person+Fare+family_size' 

y_train, x_train = dmatrices(formula_ml, data=trainSet, return_type='dataframe')

# %%
trainSet['AgeFill'] = trainSet['Age']
mean_fill = np.zeros(4)
mean_fill[0] = np.average(trainSet[trainSet['Title'] == 'Mr']['Age'].dropna())
mean_fill[1] = np.average(trainSet[trainSet['Title'] == 'Mrs']['Age'].dropna())
mean_fill[2] = np.average(trainSet[trainSet['Title'] == 'Miss']['Age'].dropna())
mean_fill[3] = np.average(trainSet[trainSet['Title'] == 'Master']['Age'].dropna())

trainSet.loc[ (trainSet.Age.isnull()) & (trainSet.Title == 'Mr') ,'AgeFill'] = mean_fill[0]
trainSet.loc[ (trainSet.Age.isnull()) & (trainSet.Title == 'Mrs') ,'AgeFill'] = mean_fill[1]
trainSet.loc[ (trainSet.Age.isnull()) & (trainSet.Title == 'Miss') ,'AgeFill'] = mean_fill[2]
trainSet.loc[ (trainSet.Age.isnull()) & (trainSet.Title == 'Master') ,'AgeFill'] = mean_fill[3]

# %%
trainSet['AgeCat'] = trainSet['AgeFill']
trainSet.loc[(trainSet.AgeFill <= 10), 'AgeCat'] = 'child'
trainSet.loc[(trainSet.AgeFill > 10) & (trainSet.AgeFill <= 30), 'AgeCat'] = 'adult'
trainSet.loc[(trainSet.AgeFill > 30) & (trainSet.AgeFill <= 60), 'AgeCat'] = 'Senior'
trainSet.loc[(trainSet.AgeFill > 60), 'AgeCat'] = 'old'

trainSet.loc[trainSet.Embarked.isnull(), 'Embarked'] = 'S'
trainSet.loc[trainSet.Cabin.isnull(), 'Cabin'] = 0.5
trainSet.loc[trainSet.Cabin.notnull(), 'Cabin'] = 1.5

# %%
trainSet.loc[trainSet.Embarked.isnull(), 'Embarked'] = 'S'
trainSet.loc[trainSet.Cabin.isnull(), 'Cabin'] = 0.5
trainSet.loc[trainSet.Cabin.notnull(), 'Cabin'] = 1.5

# %%
trainSet['family_size'] = trainSet.SibSp + trainSet.Parch
trainSet['family'] = trainSet.SibSp * trainSet.Parch

trainSet['Fare_Per_Person']=trainSet['Fare']/(trainSet['family_size'] + 1)

#Age times class
trainSet['AgeClass']=trainSet['AgeFill'] * trainSet['Pclass']
trainSet['ClassFare']=trainSet['Pclass'] * trainSet['Fare_Per_Person']

trainSet['HighLow']=trainSet['Pclass']
trainSet.loc[ (trainSet.Fare_Per_Person < 8) ,'HighLow'] = 'Low'
trainSet.loc[ (trainSet.Fare_Per_Person >= 8) ,'HighLow'] = 'High'

# %%
le = preprocessing.LabelEncoder()
'''
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit([1,5,67,100])
le.transform([1,1,100,67,5])
输出： array([0,0,3,2,1])
'''

le.fit(trainSet['Sex'] )
x_sex=le.transform(trainSet['Sex'])
trainSet['Sex']=x_sex.astype(np.float)

le.fit( trainSet['Ticket'])
x_Ticket=le.transform( trainSet['Ticket'])
trainSet['Ticket']=x_Ticket.astype(np.float)

le.fit(trainSet['Title'])
x_title=le.transform(trainSet['Title'])
trainSet['Title'] =x_title.astype(np.float)

le.fit(trainSet['HighLow'])
x_hl=le.transform(trainSet['HighLow'])
trainSet['HighLow']=x_hl.astype(np.float)


le.fit(trainSet['AgeCat'])
x_age=le.transform(trainSet['AgeCat'])
trainSet['AgeCat'] =x_age.astype(np.float)

le.fit(trainSet['Embarked'])
x_emb=le.transform(trainSet['Embarked'])
trainSet['Embarked']=x_emb.astype(np.float)

trainSet = trainSet.drop(['PassengerId','Name','Age'], axis = 1)

# %%
title = {}
for i in trainSet['Name']:
    buff = re.search(',.*\.',i).group()
    if buff not in title.keys():
        title[buff] = 0
    title[buff] += 1

# %%
formula_ml='Survived~Pclass+C(Title)+Sex+C(AgeCat)+Fare_Per_Person+Fare+family_size' 

y_train, x_train = dmatrices(formula_ml, data=trainSet, return_type='dataframe')
y_train = np.asarray(y_train).ravel()

# %%
clf=RandomForestClassifier(n_estimators=500, criterion='entropy', max_depth=5, random_state=0,
  verbose=0)
clf.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=5, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=1,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
clf.score(X_test, Y_test)
# Out:
# 0.82681564245810057

# %%
le = preprocessing.LabelEncoder()
le.fit(trainSet['Ticket'])
x_title=le.transform(trainSet['Ticket'])
bug =x_title.astype(np.float)

# %%
trainFile = r'E:\jupyter notebook\kaggle\titanic\titanic_data\test.csv'
pwd = os.getcwd()
os.chdir(os.path.dirname(trainFile))
testSet = pd.read_csv(os.path.basename(trainFile), date_parser = True)
os.chdir(pwd)
testSet[:11]
# Out:
#     PassengerId  Pclass                                          Name     Sex  \
# 0           892       3                              Kelly, Mr. James    male
# 1           893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2           894       2                     Myles, Mr. Thomas Francis    male
# 3           895       3                              Wirz, Mr. Albert    male
# 4           896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5           897       3                    Svensson, Mr. Johan Cervin    male
# 6           898       3                          Connolly, Miss. Kate  female
# 7           899       2                  Caldwell, Mr. Albert Francis    male
# 8           900       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9           901       3                       Davies, Mr. John Samuel    male
# 10          902       3                              Ilieff, Mr. Ylio    male
#
# ...

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x_train, y_train, test_size=0.3,random_state=0)

clf=RandomForestClassifier(n_estimators=500, criterion='entropy', max_depth=5, random_state=0, verbose=0)
clf.fit(X_train, Y_train)
clf.score(X_test, Y_test)
# Out:
# 0.82462686567164178

# %%
testSet.loc[testSet.Fare.isnull(), 'Fare'] = 0
testSet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           418 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB
